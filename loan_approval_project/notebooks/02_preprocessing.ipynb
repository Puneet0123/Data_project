# %% [markdown]
# ## Data Preprocessing for Loan Approval Prediction
# This notebook performs feature engineering, encoding, scaling, and splitting of data to prepare it for machine learning models.

# %% [markdown]
# ### Step 1: Import Libraries & Load Dataset

# %%
# Import Required Libraries
import pandas as pd
import numpy as np

# Load the cleaned dataset
df = pd.read_csv('../data/processed/loan_dataset.csv')
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       130.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %% [markdown]
# ### Step 2: Drop Irrelevant Columns

# %% [markdown]
# Remove unique identifiers like `Loan_ID`.

# %%
df.drop(columns=['Loan_ID'], inplace=True)

# %% [markdown]
# ### Step 3: Feature Engineering

# %% [markdown]
# Create new features to help model capture better patterns.

# %%
# Total income of applicant and co-applicant
df['Total_Income'] = df['ApplicantIncome'] + df['CoapplicantIncome']

# Income to loan ratio
df['Income_Loan_Ratio'] = df['Total_Income'] / df['LoanAmount']

# Log transform for skewed loanAmount
df['LoanAmount_log'] = np.log(df['LoanAmount'])

# Drop original columns
df.drop(['ApplicantIncome','CoapplicantIncome','LoanAmount'], axis=1, inplace=True)

# %% [markdown]
# ### Step 4: Encode Categorical Variables

# %% [markdown]
# Convert text-based categories into numerical values.

# %%
# Binary encoding 
df['Gender'] = df['Gender'].map({'Male':1, 'Female':0})
df['Married'] = df['Married'].map({'Yes':1, 'No':0})
df['Education'] = df['Education'].map({'Graduate':1, 'Not Graduate':0})
df['Self_Employed'] = df['Self_Employed'].map({'Yes':1, 'No':0})
df['Loan_Status'] = df['Loan_Status'].map({'Y':1, 'N':0})

# One-hot encoding
df = pd.get_dummies(df, columns=['Property_Area', 'Dependents'], drop_first=True)

# %% [markdown]
# ### Step 5: Outlier Removal
# Use the IQR method to remove extreme values.

# %%
Q1 = df['Total_Income'].quantile(0.25)
Q3 = df['Total_Income'].quantile(0.75)

IQR = Q3 - Q1
df = df[(df['Total_Income'] >= Q1 - 1.5 * IQR) & (df['Total_Income'] <= Q3 + 1.5 * IQR)]

# %%
df.shape
# Out:
# (564, 16)

# %% [markdown]
# ### Step 6: Feature Scaling
# Scale numerical features using StandardScaler.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_cols = ['Total_Income', 'Income_Loan_Ratio','LoanAmount_log']
df[scaled_cols] = scaler.fit_transform(df[scaled_cols])

# %% [markdown]
# ### Step 7: Split Dataset
# Split the data into training and testing sets.

# %%
from sklearn.model_selection import train_test_split

X = df.drop('Loan_Status', axis=1)
y = df['Loan_Status']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,stratify=y, random_state= 42)

# %% [markdown]
# ### Step 8: Save Processed Data
# Save the preprocessed datasets to data/processed

# %%
X_train.to_csv('../data/processed/X_train.csv', index=False)
X_test.to_csv('../data/processed/X_test.csv', index=False)
y_train.to_csv('../data/processed/y_train.csv', index=False)
y_test.to_csv('../data/processed/y_test.csv', index=False)

# %%
X_train.head()
# Out:
#      Gender  Married  Education  Self_Employed  Loan_Amount_Term  \
# 355       0        0          1              0             180.0
# 121       0        0          1              0             360.0
# 226       1        1          0              1             360.0
# 0         1        0          1              0             360.0
# 482       1        1          1              0             360.0
#
#      Credit_History  Total_Income  Income_Loan_Ratio  LoanAmount_log  \
# 355             1.0     -0.806215          -0.593364       -0.112250
# 121             1.0     -0.649658           2.230229       -2.343644
# 226             1.0     -0.397305          -0.527542        0.287494
# 0               1.0      0.096757          -0.039637        0.150031
# 482             1.0     -0.176441          -0.227362        0.114343
#
#      Property_Area_Semiurban  Property_Area_Urban  Dependents_1  Dependents_2  \
# 355                    False                 True         False         False
# 121                     True                False         False         False
# 226                    False                 True         False         False
# 0                      False                 True         False         False
# 482                     True                False         False         False
#
#      Dependents_3+
# 355          False
# 121          False
# 226          False
# 0            False
# 482          False

# %%
X.head()
# Out:
#    Gender  Married  Education  Self_Employed  Loan_Amount_Term  \
# 0       1        0          1              0             360.0
# 1       1        1          1              0             360.0
# 2       1        1          1              1             360.0
# 3       1        1          0              0             360.0
# 4       1        0          1              0             360.0
#
#    Credit_History  Total_Income  Income_Loan_Ratio  LoanAmount_log  \
# 0             1.0      0.096757          -0.039637        0.150031
# 1             1.0      0.204084           0.078843        0.114343
# 2             1.0     -1.166782          -0.018521       -1.410333
# 3             1.0     -0.305944          -0.214015       -0.034214
# 4             1.0      0.163726          -0.151058        0.336998
#
#    Property_Area_Semiurban  Property_Area_Urban  Dependents_1  Dependents_2  \
# 0                    False                 True         False         False
# 1                    False                False          True         False
# 2                    False                 True         False         False
# 3                    False                 True         False         False
# 4                    False                 True         False         False
#
#    Dependents_3+
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False

# %%
df.head()
# Out:
#    Gender  Married  Education  Self_Employed  Loan_Amount_Term  \
# 0       1        0          1              0             360.0
# 1       1        1          1              0             360.0
# 2       1        1          1              1             360.0
# 3       1        1          0              0             360.0
# 4       1        0          1              0             360.0
#
#    Credit_History  Loan_Status  Total_Income  Income_Loan_Ratio  \
# 0             1.0            1      0.096757          -0.039637
# 1             1.0            0      0.204084           0.078843
# 2             1.0            1     -1.166782          -0.018521
# 3             1.0            1     -0.305944          -0.214015
# 4             1.0            1      0.163726          -0.151058
#
#    LoanAmount_log  Property_Area_Semiurban  Property_Area_Urban  Dependents_1  \
# 0        0.150031                    False                 True         False
# 1        0.114343                    False                False          True
# 2       -1.410333                    False                 True         False
# 3       -0.034214                    False                 True         False
# 4        0.336998                    False                 True         False
#
#    Dependents_2  Dependents_3+
# 0         False          False
# 1         False          False
# 2         False          False
# 3         False          False
# 4         False          False
